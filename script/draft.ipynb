# %%
from molecules_and_features import generate_molecules

from rdkit import Chem

data_dir = "/Users/emmaphan/Documents/Comp Chem/Cl Transporter/data/training"

train_mols = generate_molecules(
    dataset_name="ChlorideTransporters-TrainingSet-1",
    data_dir=data_dir,
    endpoint=None
)

print (train_mols)
train_rdkit = {}
for i, mol in train_smiles(): 
    train_rdkit[i] = features(train_smiles[i][mol])
    i = ++i
    print (i)

# %%
from rdkit.Chem import Descriptors
# Get a list of (name, function) tuples
all_descriptors = [nm for nm, fn in rdkit.Chem.Descriptors._descList]
print(all_descriptors)

import rdkit
print(rdkit.__version__)
